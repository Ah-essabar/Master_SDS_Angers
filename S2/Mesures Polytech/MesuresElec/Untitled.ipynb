# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
# import utilsPolytech
#from utilsLaris import *
import os
os.environ['NUMEXPR_MAX_THREADS'] = '16'

# %%
raw_data = pd.read_csv("S219-Fevrier2022.csv", sep="," )
raw_data = raw_data.set_index("Date - Time") 
raw_data.index = pd.to_datetime(raw_data.index)

# %%
raw_data["2022-02-03"].plot()
# Out:
# C:\Users\ahmed\AppData\Local\Temp/ipykernel_12508/3068297961.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   raw_data["2022-02-03"].plot()
# <AxesSubplot:xlabel='Date - Time'>

# %%
a= raw_data.resample("1.33H").plot(figsize=(20, 20))
