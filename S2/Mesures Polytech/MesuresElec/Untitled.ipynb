# %%
#%matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import ipywidgets as widgets
# %matplotlib widget

# import utilsPolytech
#from utilsLaris import *
import os
os.environ['NUMEXPR_MAX_THREADS'] = '16'

# %%
data = pd.read_csv("S219-Fevrier2022.csv", sep="," )
data = data.set_index("Date - Time") 
data.index = pd.to_datetime(data.index)

# %%
data["General 219 W"].plot()
# Out:
# <AxesSubplot:xlabel='Date - Time'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data.loc["2022"].plot(figsize=(20, 5))

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot([1,2,3])
# Out:
# <div id='9260cc05-25e0-46f6-8d39-aad8f4e9310f'></div>

# %%
a= data.resample("1.33H").plot(figsize=(20, 6))

# %%
data
# Out:
#                      General 219 W  Eclairage 219 W
# Date - Time
# 2022-02-01 00:01:00         238.72              NaN
# 2022-02-01 00:02:00         321.25              NaN
# 2022-02-01 00:03:00         244.22              NaN
# 2022-02-01 00:04:00         289.36              NaN
# 2022-02-01 00:05:00         321.47              NaN
# ...                            ...              ...
# 2022-03-01 13:55:00         405.76              0.0
# 2022-03-01 13:56:00         376.04              0.0
# 2022-03-01 13:57:00         365.93              0.0
# 2022-03-01 13:58:00         404.40              0.0
# 2022-03-01 13:59:00         405.76              0.0
#
# [41159 rows x 2 columns]
