# %%
#%matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import ipywidgets as widgets
# %matplotlib widget

# import utilsPolytech
#from utilsLaris import *
import os
os.environ['NUMEXPR_MAX_THREADS'] = '16'

# %%
data = pd.read_csv("S219-Fevrier2022.csv", sep="," )
#data = pd.read_csv("S114-Fevrier2022.csv", sep="," )
data = data.set_index("Date - Time") 
data.index = pd.to_datetime(data.index)

# %%
data.fillna(0,inplace=True)
data=data.resample("2T").mean()

# %%
data["autre"] = data["General 219 W"] - data["Eclairage 219 W"]

# %%
data.plot(figsize=(20, 5))
# Out:
# <AxesSubplot:xlabel='Date - Time'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
a= data.resample("1.33H").plot(figsize=(20, 6))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data
# Out:
#                      General 219 W  Eclairage 219 W
# Date - Time
# 2022-02-01 00:00:00       273.3875              0.0
# 2022-02-01 00:05:00       284.7600              0.0
# 2022-02-01 00:10:00       285.5420              0.0
# 2022-02-01 00:15:00       279.1620              0.0
# 2022-02-01 00:20:00       286.4480              0.0
# ...                            ...              ...
# 2022-03-01 13:35:00       445.3580              0.0
# 2022-03-01 13:40:00       422.5720              0.0
# 2022-03-01 13:45:00       422.4540              0.0
# 2022-03-01 13:50:00       415.1140              0.0
# 2022-03-01 13:55:00       391.5780              0.0
#
# [8232 rows x 2 columns]
