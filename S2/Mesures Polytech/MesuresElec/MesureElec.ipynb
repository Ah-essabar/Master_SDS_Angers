# %%
import os
import wget
if os.path.isfile("utilsLaris.py")==True:
    os. remove("utilsLaris.py")
wget.download("https://raw.githubusercontent.com/Ah-essabar/LARIS01/master/utilsLaris.py")
# Out:
# 'utilsLaris.py'

# %%
#!pip install ipympl
# importing sys
#!pip install wget
#!pip install pyjanitor
# download utilsLaris form github
import janitor
import wget
import os
import ipywidgets as widgets
# %matplotlib widget
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import utilsLaris as ul

# %%
data_219 = pd.read_csv("S219-Fevrier2022.csv", sep="," )
data_219 = data_219.set_index("Date - Time") 
data_219.index = pd.to_datetime(data_219.index)
data_219 = data_219.clean_names() # janitor
data_114 = pd.read_csv("S114-Fevrier2022.csv", sep="," )
data_114 = data_114.set_index("Date - Time") 
data_114.index = pd.to_datetime(data_114.index)
data_114 = data_114.clean_names() # janitor

# %%
data_219.fillna(0,inplace=True)
data_219 = data_219.resample("5T").mean()
data_114.fillna(0,inplace=True)
data_114 = data_114.resample("5T").mean()

# %%
data_219.plot(figsize=(20, 5))
# Out:
# <AxesSubplot:xlabel='Date - Time'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data_114.plot(figsize=(20, 5))
# Out:
# <AxesSubplot:xlabel='Date - Time'>

# %%
a= data_114.resample("1.33H").plot(figsize=(20, 6))

# %%
a= data_219.resample("1.33H").plot(figsize=(20, 6))

# %%
data_
# Out:
#                      prises_114_w  general_114_w  eclairage_114_w  \
# Date - Time
# 2022-02-01 10:46:00           0.0        656.340          637.900
# 2022-02-01 10:48:00           0.0        768.415          771.645
# 2022-02-01 10:50:00           0.0        792.230          757.855
# 2022-02-01 10:52:00           0.0        768.425          752.815
# 2022-02-01 10:54:00           0.0        793.210          757.560
# ...                           ...            ...              ...
# 2022-03-01 13:50:00           0.0          0.000            0.000
# 2022-03-01 13:52:00           0.0          0.000            0.000
# 2022-03-01 13:54:00           0.0          0.000            0.000
# 2022-03-01 13:56:00           0.0          0.000            0.000
# 2022-03-01 13:58:00           0.0          0.000            0.000
#
#                      videoproj_114_w
# Date - Time
# 2022-02-01 10:46:00          170.895
# 2022-02-01 10:48:00          171.950
# ...
